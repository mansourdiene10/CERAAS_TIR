# %%
import cv2
import skimage
import numpy as np
import matplotlib.pyplot as plt
import tifffile

# %%
# !git clone https://github.com/mansourdiene10/CERAAS_TIR.git
# Out:
# Cloning into 'CERAAS_TIR'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 18 (delta 3), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (18/18), done.

# %%
img = tifffile.imread('CERAAS_TIR/0219_lwir.tif')

# %%
tifffile.imshow(img,cmap='jet')
# Out:
# (<Figure size 988.8x604.8 with 2 Axes>,
# ...
#  <matplotlib.image.AxesImage at 0x7f68901de0b8>)
